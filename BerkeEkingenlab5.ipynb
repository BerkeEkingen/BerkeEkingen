# %% [markdown]
# <a href="https://colab.research.google.com/github/BerkeEkingen/BerkeEkingen/blob/main/BerkeEkingenlab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 1
loan = loan.rename(columns={"loan_amnt": "loan_amount"})

# 2a
loan[["person_gender", "person_age", "person_income"]]

# 2b
loan.iloc[1000:2001]

# 2c
loan.iloc[::2]

# 2d
loan.loc[loan.index % 2 == 0]

# 2e
loan.iloc[:, [0, -1]]

# 3a
loan[
    (loan["person_gender"] == "female") &
    (loan["person_education"].isin(["Master", "Bachelor"])) &
    (loan["loan_amount"].between(50000, 70000))
]

# 3b
loan[
    (loan["person_gender"] == "male") &
    (loan["person_education"] != "Master") &
    (loan["person_home_ownership"] == "OWN")
]

# 3c
loan[
    loan["loan_percent_income"].between(0.4, 0.6)
]

# 3d
loan[
    loan["loan_amount"] % 10000 == 0
][["loan_amount"]]
